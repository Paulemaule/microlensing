# %%
import os
from time import time
import h5py
import numpy as np
from scipy.spatial import KDTree

# %%
# Defining the paths to the simulation results

runs_path = 'H:/Bachelorarbeit/Daten/runs/'
if not os.path.exists(runs_path): runs_path = '/work/Tit6/paul.zuern/data/runs/'

results_path = 'H:/Microlensing/data/'
if not os.path.exists(results_path): results_path = '/home/Tit5/paul.zuern/microlensing/data/'

# %%
# Defining global final variables

G = 6.6743 * 1e-11       # gravitational constant : m^3 / kg / s^2
c = 299792458            # lightspeed : m / s
J_m = 1.898 * 1e-27      # jupyter mass : kg

mass_threshold = 1e-3    # in NBODY mass units

lensing_threshold = 0.0015 # in NBODY lenght units

# %%
# Defining the neighbour finding funtion

def find_closest_naive(pos_stars, pos_ffps):
    dist = pos_stars[:,np.newaxis,:] - pos_ffps[:,:,np.newaxis]
    dist = np.linalg.norm(dist, axis = 0) # ?
    
    sort = np.argsort(dist, axis = 0) # ?
    
    return -1

def find_closest_kdtree(pos_stars, pos_ffps):
    '''Find the neighbour stars of each ffp.
    Carefull: The pos_... have to already by in only two axis!'''
    leafsize = 20
    
    tree_stars = KDTree(pos_stars.T, leafsize = leafsize)
    tree_ffps = KDTree(pos_ffps.T, leafsize = leafsize)
    
    neighbours = tree_ffps.query_ball_tree(tree_stars, lensing_threshold)
    
    return neighbours

def find_closest_digitize(pos_stars, pos_ffps):
    return -1

# %%
# Reading the data

for run in sorted(os.listdir(runs_path), key = lambda x: int(x[4:])):
    print('On ' + run)
    run_path = runs_path + run + '/'
    
    RBAR, TSCALE, N = None, None, None
    with h5py.File(run_path + 'snap.40_0.h5part') as f:
        RBAR = f[list(f.keys())[-1]]['000 Scalars'][2]
        TSCALE  = f[list(f.keys())[-1]]['000 Scalars'][10]
        N = f[list(f.keys())[-1]]['000 Scalars'][4]
        
    print(f'  General Properties: N = {int(N)}, RBAR = {RBAR:.3f}, TSCALE = {TSCALE:.3f}')
    
    # The dictionary that will store the found microlensing events
    events = {'time': [], 'id_ffp': [], 'id_star': [], 
              'axis_1': [], 'axis_2': [],
              'd': [], 'd_LS': [],
              'u': [], 'A': [], 't_E': [],
              'x1_ffp': [], 'x2_ffp': [], 'x3_ffp': [], 
              'x1_star':[], 'x2_star':[], 'x3_star':[]}
    
    snaps = sorted(filter(lambda x: ('snap' in x), os.listdir(runs_path + run)), 
                   key = lambda x: int(x.split('.')[1][3:]))
    for snap_num, snap in enumerate(snaps):
        
        time_read = time()
        print(f'    Snapshot \'{snap}\' of {len(snaps)} - remaining {len(snaps) - snap_num}')
        
        with h5py.File(run_path + snap) as f:
            
            #print(f'      Time for File reading: {time() - time_read:.2f} sec')
            time_search = time()
            
            # Sort the step keys and filter those that contain data of integer timesteps
            steps = list(filter(lambda x: f[x]['000 Scalars'][0] % 1 == 0, 
                                sorted(f.keys(),key = lambda x: int(x[5:]))))
            
            for step_num, step in enumerate(steps):
                # Read the data
                i = np.array(f[step]['032 Name'])
                m = np.array(f[step]['023 M'])
                x = np.array([f[step]['001 X1'], f[step]['002 X2'], f[step]['003 X3']])
                
                sort = np.argsort(i)
                i = i[sort]
                m = m[sort]
                x = x[:,sort]
                
                stars = m >= mass_threshold
                ffps = m < mass_threshold
                
                # The axis along which to search for microlensing
                axis = [0,1]
                
                # Search for neighbours
                neighbours = find_closest_kdtree(x[:,stars][axis,:], x[:,ffps][axis,:])
                
                for ffp_num, star_neighbour in enumerate(neighbours):
                    for star_num in star_neighbour:
                        events['time'].append(f[step]['000 Scalars'][0])
                        events['id_star'].append(i[stars][star_num])
                        events['id_ffp'].append(i[ffps][ffp_num])
                        events['axis_1'].append(axis[0])
                        events['axis_2'].append(axis[1])
                        events['d'].append(np.linalg.norm(x[:,stars][axis,:][:,star_num] - x[:,ffps][axis,:][:,ffp_num]))
                        observation_axis = list(set([0,1,2]) - set(axis))[0]
                        events['d_LS'].append(x[:,stars][observation_axis,:][star_num] - x[:,ffps][observation_axis,:][ffp_num])
                        events['u'].append(-1) # d / R_E
                        events['A'].append(-1) # (u**2 + 2) / (u * np.sqrt(u**2 + 4))
                        events['t_E'].append(-1) # R_E / v_perp
                        events['x1_star'].append(x[:,stars][:,star_num][0])
                        events['x2_star'].append(x[:,stars][:,star_num][1])
                        events['x3_star'].append(x[:,stars][:,star_num][2])
                        events['x1_ffp'].append(x[:,ffps][:,ffp_num][0])
                        events['x2_ffp'].append(x[:,ffps][:,ffp_num][1])
                        events['x3_ffp'].append(x[:,ffps][:,ffp_num][2])
                
                #break # break step loop
            #print(f'      Time for distance calculation of {len(list(steps))} steps: {time() - time_search:.2f} sec')
        
        total_time = time() - time_read
        print(f'      Total time for snapshot: {total_time:.2f} sec -> estimated remaining: {(total_time * (len(snaps) - snap_num) / 60):.1f} min')
        #break # break snap loop
    
    #print(('   '.join(['{:13s}',] * len(events.keys())).format(*events.keys())))
    #for e in np.arange(len(events['time'])):
    #    print(('   '.join(['{:13s}',] * len(events.keys())).format(*['{:.6g}'.format(events[key][e]) for key in events.keys()])))
    
    with open(results_path + 'out.txt', 'w+') as f:
        f.write(('   '.join(['{:13s}',] * len(events.keys())).format(*events.keys())) + '\n')
        for e in range(len(events['time'])):
            f.write(('   '.join(['{:13s}',] * len(events.keys())).format(*['{:.6g}'.format(events[key][e]) for key in events.keys()])) + '\n')
    
    break # break run loop

print('END')
# Out:
# On run_1
#   General Properties: N = 20000, RBAR = 1.298, TSCALE = 0.211
#     Snapshot 'snap.40_0.h5part' of 238 - remaining 238
#       Total time for snapshot: 1.81 sec -> estimated remaining: 7.2 min
#     Snapshot 'snap.40_10.h5part' of 238 - remaining 237
#       Total time for snapshot: 3.08 sec -> estimated remaining: 12.2 min
#     Snapshot 'snap.40_20.h5part' of 238 - remaining 236
#       Total time for snapshot: 3.02 sec -> estimated remaining: 11.9 min
#     Snapshot 'snap.40_30.h5part' of 238 - remaining 235
#       Total time for snapshot: 2.74 sec -> estimated remaining: 10.7 min
#     Snapshot 'snap.40_40.h5part' of 238 - remaining 234
#       Total time for snapshot: 2.52 sec -> estimated remaining: 9.8 min
#     Snapshot 'snap.40_50.h5part' of 238 - remaining 233
#       Total time for snapshot: 2.34 sec -> estimated remaining: 9.1 min
#     Snapshot 'snap.40_60.h5part' of 238 - remaining 232
#       Total time for snapshot: 2.42 sec -> estimated remaining: 9.4 min
#     Snapshot 'snap.40_70.h5part' of 238 - remaining 231
#       Total time for snapshot: 2.40 sec -> estimated remaining: 9.2 min
#     Snapshot 'snap.40_80.h5part' of 238 - remaining 230
#       Total time for snapshot: 2.49 sec -> estimated remaining: 9.5 min
#     Snapshot 'snap.40_90.h5part' of 238 - remaining 229
#       Total time for snapshot: 2.31 sec -> estimated remaining: 8.8 min
#     Snapshot 'snap.40_100.h5part' of 238 - remaining 228
#       Total time for snapshot: 2.16 sec -> estimated remaining: 8.2 min
#     Snapshot 'snap.40_110.h5part' of 238 - remaining 227
#       Total time for snapshot: 2.23 sec -> estimated remaining: 8.4 min
#     Snapshot 'snap.40_120.h5part' of 238 - remaining 226
#       Total time for snapshot: 2.31 sec -> estimated remaining: 8.7 min
#     Snapshot 'snap.40_130.h5part' of 238 - remaining 225
#       Total time for snapshot: 2.31 sec -> estimated remaining: 8.7 min
#     Snapshot 'snap.40_140.h5part' of 238 - remaining 224
#       Total time for snapshot: 2.18 sec -> estimated remaining: 8.1 min
#     Snapshot 'snap.40_150.h5part' of 238 - remaining 223
#       Total time for snapshot: 2.37 sec -> estimated remaining: 8.8 min
#     Snapshot 'snap.40_160.h5part' of 238 - remaining 222
#       Total time for snapshot: 2.17 sec -> estimated remaining: 8.0 min
#     Snapshot 'snap.40_170.h5part' of 238 - remaining 221
#       Total time for snapshot: 2.05 sec -> estimated remaining: 7.6 min
#     Snapshot 'snap.40_180.h5part' of 238 - remaining 220
#       Total time for snapshot: 2.19 sec -> estimated remaining: 8.0 min
#     Snapshot 'snap.40_190.h5part' of 238 - remaining 219
#       Total time for snapshot: 2.10 sec -> estimated remaining: 7.7 min
#     Snapshot 'snap.40_200.h5part' of 238 - remaining 218
#       Total time for snapshot: 2.38 sec -> estimated remaining: 8.7 min
#     Snapshot 'snap.40_210.h5part' of 238 - remaining 217
#       Total time for snapshot: 2.16 sec -> estimated remaining: 7.8 min
#     Snapshot 'snap.40_220.h5part' of 238 - remaining 216
#       Total time for snapshot: 2.21 sec -> estimated remaining: 7.9 min
#     Snapshot 'snap.40_230.h5part' of 238 - remaining 215
#       Total time for snapshot: 2.15 sec -> estimated remaining: 7.7 min
#     Snapshot 'snap.40_240.h5part' of 238 - remaining 214
#       Total time for snapshot: 2.22 sec -> estimated remaining: 7.9 min
#     Snapshot 'snap.40_250.h5part' of 238 - remaining 213
#       Total time for snapshot: 2.22 sec -> estimated remaining: 7.9 min
#     Snapshot 'snap.40_260.h5part' of 238 - remaining 212
#       Total time for snapshot: 2.05 sec -> estimated remaining: 7.3 min
#     Snapshot 'snap.40_270.h5part' of 238 - remaining 211
#       Total time for snapshot: 2.13 sec -> estimated remaining: 7.5 min
#     Snapshot 'snap.40_280.h5part' of 238 - remaining 210
#       Total time for snapshot: 2.25 sec -> estimated remaining: 7.9 min
#     Snapshot 'snap.40_290.h5part' of 238 - remaining 209
#       Total time for snapshot: 2.05 sec -> estimated remaining: 7.1 min
#     Snapshot 'snap.40_300.h5part' of 238 - remaining 208
#       Total time for snapshot: 2.10 sec -> estimated remaining: 7.3 min
#     Snapshot 'snap.40_310.h5part' of 238 - remaining 207
#       Total time for snapshot: 2.04 sec -> estimated remaining: 7.0 min
#     Snapshot 'snap.40_320.h5part' of 238 - remaining 206
#       Total time for snapshot: 2.17 sec -> estimated remaining: 7.4 min
#     Snapshot 'snap.40_330.h5part' of 238 - remaining 205
#       Total time for snapshot: 2.07 sec -> estimated remaining: 7.1 min
#     Snapshot 'snap.40_340.h5part' of 238 - remaining 204
#       Total time for snapshot: 2.25 sec -> estimated remaining: 7.6 min
#     Snapshot 'snap.40_350.h5part' of 238 - remaining 203
#       Total time for snapshot: 2.02 sec -> estimated remaining: 6.8 min
#     Snapshot 'snap.40_360.h5part' of 238 - remaining 202
#       Total time for snapshot: 2.04 sec -> estimated remaining: 6.9 min
#     Snapshot 'snap.40_370.h5part' of 238 - remaining 201
#       Total time for snapshot: 2.05 sec -> estimated remaining: 6.9 min
#     Snapshot 'snap.40_380.h5part' of 238 - remaining 200
#       Total time for snapshot: 2.03 sec -> estimated remaining: 6.8 min
#     Snapshot 'snap.40_390.h5part' of 238 - remaining 199
#       Total time for snapshot: 2.16 sec -> estimated remaining: 7.1 min
#     Snapshot 'snap.40_400.h5part' of 238 - remaining 198
#       Total time for snapshot: 2.34 sec -> estimated remaining: 7.7 min
#     Snapshot 'snap.40_410.h5part' of 238 - remaining 197
#       Total time for snapshot: 2.30 sec -> estimated remaining: 7.5 min
#     Snapshot 'snap.40_420.h5part' of 238 - remaining 196
#       Total time for snapshot: 2.05 sec -> estimated remaining: 6.7 min
#     Snapshot 'snap.40_430.h5part' of 238 - remaining 195
#       Total time for snapshot: 2.12 sec -> estimated remaining: 6.9 min
#     Snapshot 'snap.40_440.h5part' of 238 - remaining 194
#       Total time for snapshot: 2.32 sec -> estimated remaining: 7.5 min
#     Snapshot 'snap.40_450.h5part' of 238 - remaining 193
#       Total time for snapshot: 2.09 sec -> estimated remaining: 6.7 min
#     Snapshot 'snap.40_460.h5part' of 238 - remaining 192
#       Total time for snapshot: 2.10 sec -> estimated remaining: 6.7 min
#     Snapshot 'snap.40_470.h5part' of 238 - remaining 191
#       Total time for snapshot: 1.97 sec -> estimated remaining: 6.3 min
#     Snapshot 'snap.40_480.h5part' of 238 - remaining 190
#       Total time for snapshot: 2.40 sec -> estimated remaining: 7.6 min
#     Snapshot 'snap.40_490.h5part' of 238 - remaining 189
#       Total time for snapshot: 2.20 sec -> estimated remaining: 6.9 min
#     Snapshot 'snap.40_500.h5part' of 238 - remaining 188
#       Total time for snapshot: 2.02 sec -> estimated remaining: 6.3 min
#     Snapshot 'snap.40_510.h5part' of 238 - remaining 187
#       Total time for snapshot: 2.16 sec -> estimated remaining: 6.7 min
#     Snapshot 'snap.40_520.h5part' of 238 - remaining 186
#       Total time for snapshot: 2.02 sec -> estimated remaining: 6.3 min
#     Snapshot 'snap.40_530.h5part' of 238 - remaining 185
#       Total time for snapshot: 2.05 sec -> estimated remaining: 6.3 min
#     Snapshot 'snap.40_540.h5part' of 238 - remaining 184
#       Total time for snapshot: 2.05 sec -> estimated remaining: 6.3 min
#     Snapshot 'snap.40_550.h5part' of 238 - remaining 183
#       Total time for snapshot: 2.28 sec -> estimated remaining: 6.9 min
#     Snapshot 'snap.40_560.h5part' of 238 - remaining 182
#       Total time for snapshot: 1.97 sec -> estimated remaining: 6.0 min
#     Snapshot 'snap.40_570.h5part' of 238 - remaining 181
#       Total time for snapshot: 2.06 sec -> estimated remaining: 6.2 min
#     Snapshot 'snap.40_580.h5part' of 238 - remaining 180
#       Total time for snapshot: 2.06 sec -> estimated remaining: 6.2 min
#     Snapshot 'snap.40_590.h5part' of 238 - remaining 179
#       Total time for snapshot: 2.01 sec -> estimated remaining: 6.0 min
#     Snapshot 'snap.40_600.h5part' of 238 - remaining 178
#       Total time for snapshot: 2.16 sec -> estimated remaining: 6.4 min
#     Snapshot 'snap.40_610.h5part' of 238 - remaining 177
#       Total time for snapshot: 1.99 sec -> estimated remaining: 5.9 min
#     Snapshot 'snap.40_620.h5part' of 238 - remaining 176
#       Total time for snapshot: 2.08 sec -> estimated remaining: 6.1 min
#     Snapshot 'snap.40_630.h5part' of 238 - remaining 175
#       Total time for snapshot: 2.02 sec -> estimated remaining: 5.9 min
#     Snapshot 'snap.40_640.h5part' of 238 - remaining 174
#       Total time for snapshot: 2.50 sec -> estimated remaining: 7.3 min
#     Snapshot 'snap.40_650.h5part' of 238 - remaining 173
#       Total time for snapshot: 2.01 sec -> estimated remaining: 5.8 min
#     Snapshot 'snap.40_660.h5part' of 238 - remaining 172
#       Total time for snapshot: 2.04 sec -> estimated remaining: 5.8 min
#     Snapshot 'snap.40_670.h5part' of 238 - remaining 171
#       Total time for snapshot: 2.00 sec -> estimated remaining: 5.7 min
#     Snapshot 'snap.40_680.h5part' of 238 - remaining 170
#       Total time for snapshot: 2.00 sec -> estimated remaining: 5.7 min
#     Snapshot 'snap.40_690.h5part' of 238 - remaining 169
#       Total time for snapshot: 1.88 sec -> estimated remaining: 5.3 min
#     Snapshot 'snap.40_700.h5part' of 238 - remaining 168
#       Total time for snapshot: 1.99 sec -> estimated remaining: 5.6 min
#     Snapshot 'snap.40_710.h5part' of 238 - remaining 167
#       Total time for snapshot: 2.05 sec -> estimated remaining: 5.7 min
#     Snapshot 'snap.40_720.h5part' of 238 - remaining 166
#       Total time for snapshot: 1.97 sec -> estimated remaining: 5.5 min
#     Snapshot 'snap.40_730.h5part' of 238 - remaining 165
#       Total time for snapshot: 2.71 sec -> estimated remaining: 7.5 min
#     Snapshot 'snap.40_740.h5part' of 238 - remaining 164
#       Total time for snapshot: 1.96 sec -> estimated remaining: 5.4 min
#     Snapshot 'snap.40_750.h5part' of 238 - remaining 163
#       Total time for snapshot: 1.96 sec -> estimated remaining: 5.3 min
#     Snapshot 'snap.40_760.h5part' of 238 - remaining 162
#       Total time for snapshot: 1.96 sec -> estimated remaining: 5.3 min
#     Snapshot 'snap.40_770.h5part' of 238 - remaining 161
#       Total time for snapshot: 2.02 sec -> estimated remaining: 5.4 min
#     Snapshot 'snap.40_780.h5part' of 238 - remaining 160
#       Total time for snapshot: 2.07 sec -> estimated remaining: 5.5 min
#     Snapshot 'snap.40_790.h5part' of 238 - remaining 159
#       Total time for snapshot: 1.92 sec -> estimated remaining: 5.1 min
#     Snapshot 'snap.40_800.h5part' of 238 - remaining 158
#       Total time for snapshot: 2.08 sec -> estimated remaining: 5.5 min
#     Snapshot 'snap.40_810.h5part' of 238 - remaining 157
#       Total time for snapshot: 2.14 sec -> estimated remaining: 5.6 min
#     Snapshot 'snap.40_820.h5part' of 238 - remaining 156
#       Total time for snapshot: 2.04 sec -> estimated remaining: 5.3 min
#     Snapshot 'snap.40_830.h5part' of 238 - remaining 155
#       Total time for snapshot: 2.15 sec -> estimated remaining: 5.5 min
#     Snapshot 'snap.40_840.h5part' of 238 - remaining 154
#       Total time for snapshot: 1.93 sec -> estimated remaining: 4.9 min
#     Snapshot 'snap.40_850.h5part' of 238 - remaining 153
#       Total time for snapshot: 1.98 sec -> estimated remaining: 5.0 min
#     Snapshot 'snap.40_860.h5part' of 238 - remaining 152
#       Total time for snapshot: 1.97 sec -> estimated remaining: 5.0 min
#     Snapshot 'snap.40_870.h5part' of 238 - remaining 151
#       Total time for snapshot: 2.22 sec -> estimated remaining: 5.6 min
#     Snapshot 'snap.40_880.h5part' of 238 - remaining 150
#       Total time for snapshot: 1.98 sec -> estimated remaining: 5.0 min
#     Snapshot 'snap.40_890.h5part' of 238 - remaining 149
#       Total time for snapshot: 2.18 sec -> estimated remaining: 5.4 min
#     Snapshot 'snap.40_900.h5part' of 238 - remaining 148
#       Total time for snapshot: 2.07 sec -> estimated remaining: 5.1 min
#     Snapshot 'snap.40_910.h5part' of 238 - remaining 147
#       Total time for snapshot: 1.95 sec -> estimated remaining: 4.8 min
#     Snapshot 'snap.40_920.h5part' of 238 - remaining 146
#       Total time for snapshot: 2.19 sec -> estimated remaining: 5.3 min
#     Snapshot 'snap.40_930.h5part' of 238 - remaining 145
#       Total time for snapshot: 1.93 sec -> estimated remaining: 4.7 min
#     Snapshot 'snap.40_940.h5part' of 238 - remaining 144
#       Total time for snapshot: 2.08 sec -> estimated remaining: 5.0 min
#     Snapshot 'snap.40_950.h5part' of 238 - remaining 143
#       Total time for snapshot: 2.05 sec -> estimated remaining: 4.9 min
#     Snapshot 'snap.40_960.h5part' of 238 - remaining 142
#       Total time for snapshot: 2.16 sec -> estimated remaining: 5.1 min
#     Snapshot 'snap.40_970.h5part' of 238 - remaining 141
#       Total time for snapshot: 2.27 sec -> estimated remaining: 5.3 min
#     Snapshot 'snap.40_980.h5part' of 238 - remaining 140
#       Total time for snapshot: 1.86 sec -> estimated remaining: 4.3 min
#     Snapshot 'snap.40_990.h5part' of 238 - remaining 139
#       Total time for snapshot: 1.93 sec -> estimated remaining: 4.5 min
#     Snapshot 'snap.40_1000.h5part' of 238 - remaining 138
#       Total time for snapshot: 2.02 sec -> estimated remaining: 4.7 min
#     Snapshot 'snap.40_1010.h5part' of 238 - remaining 137
#       Total time for snapshot: 1.91 sec -> estimated remaining: 4.4 min
#     Snapshot 'snap.40_1020.h5part' of 238 - remaining 136
#       Total time for snapshot: 2.07 sec -> estimated remaining: 4.7 min
#     Snapshot 'snap.40_1030.h5part' of 238 - remaining 135
#       Total time for snapshot: 1.87 sec -> estimated remaining: 4.2 min
#     Snapshot 'snap.40_1040.h5part' of 238 - remaining 134
#       Total time for snapshot: 1.86 sec -> estimated remaining: 4.2 min
#     Snapshot 'snap.40_1050.h5part' of 238 - remaining 133
#       Total time for snapshot: 2.14 sec -> estimated remaining: 4.7 min
#     Snapshot 'snap.40_1060.h5part' of 238 - remaining 132
#       Total time for snapshot: 1.94 sec -> estimated remaining: 4.3 min
#     Snapshot 'snap.40_1070.h5part' of 238 - remaining 131
#       Total time for snapshot: 2.00 sec -> estimated remaining: 4.4 min
#     Snapshot 'snap.40_1080.h5part' of 238 - remaining 130
#       Total time for snapshot: 2.12 sec -> estimated remaining: 4.6 min
#     Snapshot 'snap.40_1090.h5part' of 238 - remaining 129
#       Total time for snapshot: 1.91 sec -> estimated remaining: 4.1 min
#     Snapshot 'snap.40_1100.h5part' of 238 - remaining 128
#       Total time for snapshot: 2.11 sec -> estimated remaining: 4.5 min
#     Snapshot 'snap.40_1110.h5part' of 238 - remaining 127
#       Total time for snapshot: 1.97 sec -> estimated remaining: 4.2 min
#     Snapshot 'snap.40_1120.h5part' of 238 - remaining 126
#       Total time for snapshot: 2.21 sec -> estimated remaining: 4.7 min
#     Snapshot 'snap.40_1130.h5part' of 238 - remaining 125
#       Total time for snapshot: 1.87 sec -> estimated remaining: 3.9 min
#     Snapshot 'snap.40_1140.h5part' of 238 - remaining 124
#       Total time for snapshot: 2.28 sec -> estimated remaining: 4.7 min
#     Snapshot 'snap.40_1150.h5part' of 238 - remaining 123
#       Total time for snapshot: 2.14 sec -> estimated remaining: 4.4 min
#     Snapshot 'snap.40_1160.h5part' of 238 - remaining 122
#       Total time for snapshot: 1.94 sec -> estimated remaining: 3.9 min
#     Snapshot 'snap.40_1170.h5part' of 238 - remaining 121
#       Total time for snapshot: 2.11 sec -> estimated remaining: 4.2 min
#     Snapshot 'snap.40_1180.h5part' of 238 - remaining 120
#       Total time for snapshot: 1.98 sec -> estimated remaining: 4.0 min
#     Snapshot 'snap.40_1190.h5part' of 238 - remaining 119
#       Total time for snapshot: 1.93 sec -> estimated remaining: 3.8 min
#     Snapshot 'snap.40_1200.h5part' of 238 - remaining 118
#       Total time for snapshot: 2.07 sec -> estimated remaining: 4.1 min
#     Snapshot 'snap.40_1210.h5part' of 238 - remaining 117
#       Total time for snapshot: 2.00 sec -> estimated remaining: 3.9 min
#     Snapshot 'snap.40_1220.h5part' of 238 - remaining 116
#       Total time for snapshot: 2.30 sec -> estimated remaining: 4.4 min
#     Snapshot 'snap.40_1230.h5part' of 238 - remaining 115
#       Total time for snapshot: 1.88 sec -> estimated remaining: 3.6 min
#     Snapshot 'snap.40_1240.h5part' of 238 - remaining 114
#       Total time for snapshot: 2.10 sec -> estimated remaining: 4.0 min
#     Snapshot 'snap.40_1250.h5part' of 238 - remaining 113
#       Total time for snapshot: 2.00 sec -> estimated remaining: 3.8 min
#     Snapshot 'snap.40_1260.h5part' of 238 - remaining 112
#       Total time for snapshot: 1.95 sec -> estimated remaining: 3.6 min
#     Snapshot 'snap.40_1270.h5part' of 238 - remaining 111
#       Total time for snapshot: 2.04 sec -> estimated remaining: 3.8 min
#     Snapshot 'snap.40_1280.h5part' of 238 - remaining 110
#       Total time for snapshot: 2.01 sec -> estimated remaining: 3.7 min
#     Snapshot 'snap.40_1290.h5part' of 238 - remaining 109
#       Total time for snapshot: 2.14 sec -> estimated remaining: 3.9 min
#     Snapshot 'snap.40_1300.h5part' of 238 - remaining 108
#       Total time for snapshot: 2.06 sec -> estimated remaining: 3.7 min
#     Snapshot 'snap.40_1310.h5part' of 238 - remaining 107
#       Total time for snapshot: 2.15 sec -> estimated remaining: 3.8 min
#     Snapshot 'snap.40_1320.h5part' of 238 - remaining 106
#       Total time for snapshot: 2.02 sec -> estimated remaining: 3.6 min
#     Snapshot 'snap.40_1330.h5part' of 238 - remaining 105
#       Total time for snapshot: 2.03 sec -> estimated remaining: 3.6 min
#     Snapshot 'snap.40_1340.h5part' of 238 - remaining 104
#       Total time for snapshot: 1.94 sec -> estimated remaining: 3.4 min
#     Snapshot 'snap.40_1350.h5part' of 238 - remaining 103
#       Total time for snapshot: 2.12 sec -> estimated remaining: 3.6 min
#     Snapshot 'snap.40_1360.h5part' of 238 - remaining 102
#       Total time for snapshot: 1.94 sec -> estimated remaining: 3.3 min
#     Snapshot 'snap.40_1370.h5part' of 238 - remaining 101
#       Total time for snapshot: 2.14 sec -> estimated remaining: 3.6 min
#     Snapshot 'snap.40_1380.h5part' of 238 - remaining 100
#       Total time for snapshot: 2.05 sec -> estimated remaining: 3.4 min
#     Snapshot 'snap.40_1390.h5part' of 238 - remaining 99
#       Total time for snapshot: 2.27 sec -> estimated remaining: 3.7 min
#     Snapshot 'snap.40_1400.h5part' of 238 - remaining 98
#       Total time for snapshot: 2.01 sec -> estimated remaining: 3.3 min
#     Snapshot 'snap.40_1410.h5part' of 238 - remaining 97
#       Total time for snapshot: 1.89 sec -> estimated remaining: 3.1 min
#     Snapshot 'snap.40_1420.h5part' of 238 - remaining 96
#       Total time for snapshot: 1.99 sec -> estimated remaining: 3.2 min
#     Snapshot 'snap.40_1430.h5part' of 238 - remaining 95
#       Total time for snapshot: 1.97 sec -> estimated remaining: 3.1 min
#     Snapshot 'snap.40_1440.h5part' of 238 - remaining 94
#       Total time for snapshot: 2.11 sec -> estimated remaining: 3.3 min
#     Snapshot 'snap.40_1450.h5part' of 238 - remaining 93
#       Total time for snapshot: 1.94 sec -> estimated remaining: 3.0 min
#     Snapshot 'snap.40_1460.h5part' of 238 - remaining 92
#       Total time for snapshot: 1.95 sec -> estimated remaining: 3.0 min
#     Snapshot 'snap.40_1470.h5part' of 238 - remaining 91
#       Total time for snapshot: 2.06 sec -> estimated remaining: 3.1 min
#     Snapshot 'snap.40_1480.h5part' of 238 - remaining 90
#       Total time for snapshot: 2.08 sec -> estimated remaining: 3.1 min
#     Snapshot 'snap.40_1490.h5part' of 238 - remaining 89
#       Total time for snapshot: 2.14 sec -> estimated remaining: 3.2 min
#     Snapshot 'snap.40_1500.h5part' of 238 - remaining 88
#       Total time for snapshot: 2.25 sec -> estimated remaining: 3.3 min
#     Snapshot 'snap.40_1510.h5part' of 238 - remaining 87
#       Total time for snapshot: 2.15 sec -> estimated remaining: 3.1 min
#     Snapshot 'snap.40_1520.h5part' of 238 - remaining 86
#       Total time for snapshot: 1.92 sec -> estimated remaining: 2.7 min
#     Snapshot 'snap.40_1530.h5part' of 238 - remaining 85
#       Total time for snapshot: 1.90 sec -> estimated remaining: 2.7 min
#     Snapshot 'snap.40_1540.h5part' of 238 - remaining 84
#       Total time for snapshot: 2.12 sec -> estimated remaining: 3.0 min
#     Snapshot 'snap.40_1550.h5part' of 238 - remaining 83
#       Total time for snapshot: 1.95 sec -> estimated remaining: 2.7 min
#     Snapshot 'snap.40_1560.h5part' of 238 - remaining 82
#       Total time for snapshot: 2.01 sec -> estimated remaining: 2.7 min
#     Snapshot 'snap.40_1570.h5part' of 238 - remaining 81
#       Total time for snapshot: 2.07 sec -> estimated remaining: 2.8 min
#     Snapshot 'snap.40_1580.h5part' of 238 - remaining 80
#       Total time for snapshot: 2.16 sec -> estimated remaining: 2.9 min
#     Snapshot 'snap.40_1590.h5part' of 238 - remaining 79
#       Total time for snapshot: 2.15 sec -> estimated remaining: 2.8 min
#     Snapshot 'snap.40_1600.h5part' of 238 - remaining 78
#       Total time for snapshot: 1.94 sec -> estimated remaining: 2.5 min
#     Snapshot 'snap.40_1610.h5part' of 238 - remaining 77
#       Total time for snapshot: 2.00 sec -> estimated remaining: 2.6 min
#     Snapshot 'snap.40_1620.h5part' of 238 - remaining 76
#       Total time for snapshot: 1.92 sec -> estimated remaining: 2.4 min
#     Snapshot 'snap.40_1630.h5part' of 238 - remaining 75
#       Total time for snapshot: 2.01 sec -> estimated remaining: 2.5 min
#     Snapshot 'snap.40_1640.h5part' of 238 - remaining 74
#       Total time for snapshot: 2.14 sec -> estimated remaining: 2.6 min
#     Snapshot 'snap.40_1650.h5part' of 238 - remaining 73
#       Total time for snapshot: 2.06 sec -> estimated remaining: 2.5 min
#     Snapshot 'snap.40_1660.h5part' of 238 - remaining 72
#       Total time for snapshot: 2.29 sec -> estimated remaining: 2.7 min
#     Snapshot 'snap.40_1670.h5part' of 238 - remaining 71
#       Total time for snapshot: 2.14 sec -> estimated remaining: 2.5 min
#     Snapshot 'snap.40_1680.h5part' of 238 - remaining 70
#       Total time for snapshot: 1.88 sec -> estimated remaining: 2.2 min
#     Snapshot 'snap.40_1690.h5part' of 238 - remaining 69
#       Total time for snapshot: 2.11 sec -> estimated remaining: 2.4 min
#     Snapshot 'snap.40_1700.h5part' of 238 - remaining 68
#       Total time for snapshot: 1.98 sec -> estimated remaining: 2.2 min
#     Snapshot 'snap.40_1710.h5part' of 238 - remaining 67
#       Total time for snapshot: 2.04 sec -> estimated remaining: 2.3 min
#     Snapshot 'snap.40_1720.h5part' of 238 - remaining 66
#       Total time for snapshot: 2.04 sec -> estimated remaining: 2.2 min
#     Snapshot 'snap.40_1730.h5part' of 238 - remaining 65
#       Total time for snapshot: 1.92 sec -> estimated remaining: 2.1 min
#     Snapshot 'snap.40_1740.h5part' of 238 - remaining 64
#       Total time for snapshot: 2.05 sec -> estimated remaining: 2.2 min
#     Snapshot 'snap.40_1750.h5part' of 238 - remaining 63
#       Total time for snapshot: 1.98 sec -> estimated remaining: 2.1 min
#     Snapshot 'snap.40_1760.h5part' of 238 - remaining 62
#       Total time for snapshot: 1.91 sec -> estimated remaining: 2.0 min
#     Snapshot 'snap.40_1770.h5part' of 238 - remaining 61
#       Total time for snapshot: 1.94 sec -> estimated remaining: 2.0 min
#     Snapshot 'snap.40_1780.h5part' of 238 - remaining 60
#       Total time for snapshot: 1.88 sec -> estimated remaining: 1.9 min
#     Snapshot 'snap.40_1790.h5part' of 238 - remaining 59
#       Total time for snapshot: 2.18 sec -> estimated remaining: 2.1 min
#     Snapshot 'snap.40_1800.h5part' of 238 - remaining 58
#       Total time for snapshot: 1.92 sec -> estimated remaining: 1.9 min
#     Snapshot 'snap.40_1810.h5part' of 238 - remaining 57
#       Total time for snapshot: 1.92 sec -> estimated remaining: 1.8 min
#     Snapshot 'snap.40_1820.h5part' of 238 - remaining 56
#       Total time for snapshot: 1.92 sec -> estimated remaining: 1.8 min
#     Snapshot 'snap.40_1830.h5part' of 238 - remaining 55
#       Total time for snapshot: 1.84 sec -> estimated remaining: 1.7 min
#     Snapshot 'snap.40_1840.h5part' of 238 - remaining 54
#       Total time for snapshot: 1.96 sec -> estimated remaining: 1.8 min
#     Snapshot 'snap.40_1850.h5part' of 238 - remaining 53
#       Total time for snapshot: 1.92 sec -> estimated remaining: 1.7 min
#     Snapshot 'snap.40_1860.h5part' of 238 - remaining 52
#       Total time for snapshot: 1.84 sec -> estimated remaining: 1.6 min
#     Snapshot 'snap.40_1870.h5part' of 238 - remaining 51
#       Total time for snapshot: 2.09 sec -> estimated remaining: 1.8 min
#     Snapshot 'snap.40_1880.h5part' of 238 - remaining 50
#       Total time for snapshot: 1.89 sec -> estimated remaining: 1.6 min
#     Snapshot 'snap.40_1890.h5part' of 238 - remaining 49
#       Total time for snapshot: 1.93 sec -> estimated remaining: 1.6 min
#     Snapshot 'snap.40_1900.h5part' of 238 - remaining 48
#       Total time for snapshot: 1.93 sec -> estimated remaining: 1.5 min
#     Snapshot 'snap.40_1910.h5part' of 238 - remaining 47
#       Total time for snapshot: 2.06 sec -> estimated remaining: 1.6 min
#     Snapshot 'snap.40_1920.h5part' of 238 - remaining 46
#       Total time for snapshot: 2.02 sec -> estimated remaining: 1.5 min
#     Snapshot 'snap.40_1930.h5part' of 238 - remaining 45
#       Total time for snapshot: 2.01 sec -> estimated remaining: 1.5 min
#     Snapshot 'snap.40_1940.h5part' of 238 - remaining 44
#       Total time for snapshot: 2.12 sec -> estimated remaining: 1.6 min
#     Snapshot 'snap.40_1950.h5part' of 238 - remaining 43
#       Total time for snapshot: 1.98 sec -> estimated remaining: 1.4 min
#     Snapshot 'snap.40_1960.h5part' of 238 - remaining 42
#       Total time for snapshot: 1.80 sec -> estimated remaining: 1.3 min
#     Snapshot 'snap.40_1970.h5part' of 238 - remaining 41
#       Total time for snapshot: 2.25 sec -> estimated remaining: 1.5 min
#     Snapshot 'snap.40_1980.h5part' of 238 - remaining 40
#       Total time for snapshot: 1.88 sec -> estimated remaining: 1.3 min
#     Snapshot 'snap.40_1990.h5part' of 238 - remaining 39
#       Total time for snapshot: 1.89 sec -> estimated remaining: 1.2 min
#     Snapshot 'snap.40_2000.h5part' of 238 - remaining 38
#       Total time for snapshot: 1.96 sec -> estimated remaining: 1.2 min
#     Snapshot 'snap.40_2010.h5part' of 238 - remaining 37
#       Total time for snapshot: 1.74 sec -> estimated remaining: 1.1 min
#     Snapshot 'snap.40_2020.h5part' of 238 - remaining 36
#       Total time for snapshot: 2.15 sec -> estimated remaining: 1.3 min
#     Snapshot 'snap.40_2030.h5part' of 238 - remaining 35
#       Total time for snapshot: 2.00 sec -> estimated remaining: 1.2 min
#     Snapshot 'snap.40_2040.h5part' of 238 - remaining 34
#       Total time for snapshot: 2.29 sec -> estimated remaining: 1.3 min
#     Snapshot 'snap.40_2050.h5part' of 238 - remaining 33
#       Total time for snapshot: 1.96 sec -> estimated remaining: 1.1 min
#     Snapshot 'snap.40_2060.h5part' of 238 - remaining 32
#       Total time for snapshot: 2.24 sec -> estimated remaining: 1.2 min
#     Snapshot 'snap.40_2070.h5part' of 238 - remaining 31
#       Total time for snapshot: 1.91 sec -> estimated remaining: 1.0 min
#     Snapshot 'snap.40_2080.h5part' of 238 - remaining 30
#       Total time for snapshot: 1.93 sec -> estimated remaining: 1.0 min
#     Snapshot 'snap.40_2090.h5part' of 238 - remaining 29
#       Total time for snapshot: 1.91 sec -> estimated remaining: 0.9 min
#     Snapshot 'snap.40_2100.h5part' of 238 - remaining 28
#       Total time for snapshot: 1.94 sec -> estimated remaining: 0.9 min
#     Snapshot 'snap.40_2110.h5part' of 238 - remaining 27
#       Total time for snapshot: 1.80 sec -> estimated remaining: 0.8 min
#     Snapshot 'snap.40_2120.h5part' of 238 - remaining 26
#       Total time for snapshot: 1.99 sec -> estimated remaining: 0.9 min
#     Snapshot 'snap.40_2130.h5part' of 238 - remaining 25
#       Total time for snapshot: 1.99 sec -> estimated remaining: 0.8 min
#     Snapshot 'snap.40_2140.h5part' of 238 - remaining 24
#       Total time for snapshot: 1.74 sec -> estimated remaining: 0.7 min
#     Snapshot 'snap.40_2150.h5part' of 238 - remaining 23
#       Total time for snapshot: 1.87 sec -> estimated remaining: 0.7 min
#     Snapshot 'snap.40_2160.h5part' of 238 - remaining 22
#       Total time for snapshot: 1.90 sec -> estimated remaining: 0.7 min
#     Snapshot 'snap.40_2170.h5part' of 238 - remaining 21
#       Total time for snapshot: 1.82 sec -> estimated remaining: 0.6 min
#     Snapshot 'snap.40_2180.h5part' of 238 - remaining 20
#       Total time for snapshot: 1.94 sec -> estimated remaining: 0.6 min
#     Snapshot 'snap.40_2190.h5part' of 238 - remaining 19
#       Total time for snapshot: 1.92 sec -> estimated remaining: 0.6 min
#     Snapshot 'snap.40_2200.h5part' of 238 - remaining 18
#       Total time for snapshot: 1.88 sec -> estimated remaining: 0.6 min
#     Snapshot 'snap.40_2210.h5part' of 238 - remaining 17
#       Total time for snapshot: 2.02 sec -> estimated remaining: 0.6 min
#     Snapshot 'snap.40_2220.h5part' of 238 - remaining 16
#       Total time for snapshot: 1.81 sec -> estimated remaining: 0.5 min
#     Snapshot 'snap.40_2230.h5part' of 238 - remaining 15
#       Total time for snapshot: 2.00 sec -> estimated remaining: 0.5 min
#     Snapshot 'snap.40_2240.h5part' of 238 - remaining 14
#       Total time for snapshot: 1.78 sec -> estimated remaining: 0.4 min
#     Snapshot 'snap.40_2250.h5part' of 238 - remaining 13
#       Total time for snapshot: 1.91 sec -> estimated remaining: 0.4 min
#     Snapshot 'snap.40_2260.h5part' of 238 - remaining 12
#       Total time for snapshot: 1.91 sec -> estimated remaining: 0.4 min
#     Snapshot 'snap.40_2270.h5part' of 238 - remaining 11
#       Total time for snapshot: 1.81 sec -> estimated remaining: 0.3 min
#     Snapshot 'snap.40_2280.h5part' of 238 - remaining 10
#       Total time for snapshot: 1.92 sec -> estimated remaining: 0.3 min
#     Snapshot 'snap.40_2290.h5part' of 238 - remaining 9
#       Total time for snapshot: 2.08 sec -> estimated remaining: 0.3 min
#     Snapshot 'snap.40_2300.h5part' of 238 - remaining 8
#       Total time for snapshot: 1.82 sec -> estimated remaining: 0.2 min
#     Snapshot 'snap.40_2310.h5part' of 238 - remaining 7
#       Total time for snapshot: 2.08 sec -> estimated remaining: 0.2 min
#     Snapshot 'snap.40_2320.h5part' of 238 - remaining 6
#       Total time for snapshot: 1.72 sec -> estimated remaining: 0.2 min
#     Snapshot 'snap.40_2330.h5part' of 238 - remaining 5
#       Total time for snapshot: 1.80 sec -> estimated remaining: 0.2 min
#     Snapshot 'snap.40_2340.h5part' of 238 - remaining 4
#       Total time for snapshot: 1.78 sec -> estimated remaining: 0.1 min
#     Snapshot 'snap.40_2350.h5part' of 238 - remaining 3
#       Total time for snapshot: 1.95 sec -> estimated remaining: 0.1 min
#     Snapshot 'snap.40_2360.h5part' of 238 - remaining 2
#       Total time for snapshot: 1.76 sec -> estimated remaining: 0.1 min
#     Snapshot 'snap.40_2370.h5part' of 238 - remaining 1
#       Total time for snapshot: 0.31 sec -> estimated remaining: 0.0 min
# END
